# %%
import db_builder.db_handler as dbh
import numpy as np
from torchvision import transforms, datasets
from tqdm import tqdm
import logging
from getpass import getpass
from PIL import Image
import torchvision.models as models
import torch.nn as nn
import torch
import os
import cv2
from collections import Counter

# %%
logging.getLogger('sqlalchemy.engine').propagate = False

db_params = {
    'user': 'postgres',
    'password': getpass('Please enter DB pw'),  # enter your DB password
    'host': 'localhost',  # 'localhost' or IP address
    'port': '5432',  # '5432'
    'database': 'ttdatabase_test',  #tensionTerminator
}
toolcheck = dbh.DB_Conn(db_params)
toolcheck.connect()
engine = toolcheck.get_engine()
# Out:
# Connected to PostgreSQL, DB: ttdatabase_test

# %%
unlabeled_loops = toolcheck.get_unlabeled_loop_id()
# Out:
# 2023-11-28 18:41:33,977 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2023-11-28 18:41:33,978 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-11-28 18:41:33,979 INFO sqlalchemy.engine.Engine select current_schema()
# 2023-11-28 18:41:33,979 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-11-28 18:41:33,981 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2023-11-28 18:41:33,981 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2023-11-28 18:41:33,982 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:41:33,983 INFO sqlalchemy.engine.Engine SELECT id FROM loop WHERE human_labeled = false
# 2023-11-28 18:41:33,983 INFO sqlalchemy.engine.Engine [generated in 0.00034s] {}

# %%
def time_formatter(total_seconds):

    hours = total_seconds // 3600
    remaining_seconds = total_seconds % 3600
    minutes = remaining_seconds // 60
    seconds = remaining_seconds % 60
    
    formatted_time = f"{hours:02d}:{minutes:02d}:{seconds:02d}"
    return formatted_time

# %%
def trigger_crop(image):
    crop_box = (400, 450, 550, 550)
    cropped_image = transforms.functional.crop(image, *crop_box)
    return cropped_image

# %%
def video_to_image_converter(source_path: str, output_path: str, crop=False):
    vidcap = cv2.VideoCapture(source_path)
    os.makedirs(output_path, exist_ok=True)
    count = 0

    total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
    #fps = int(vidcap.get(cv2.CAP_PROP_FPS))
    fps = 30

    while count < total_frames:
        success, image = vidcap.read()

        if count % int(fps) == 0:
            if not image is None and not image.size == 0:
                transform_test = transforms.ToPILImage()
                image = transform_test(image)
                if crop:
                    image = trigger_crop(image)
                image = np.asarray(image)
                cv2.imwrite(f"{output_path}/{count}.png", image)  # save frame as PNG file

        count += 1

    vidcap.release()
    cv2.destroyAllWindows()

# %%
def checkImage(path: str, transfer_model, orig_set, transforms_wt):
    img = Image.open(path)
    img_tensor = transforms_wt(img).unsqueeze(0)
    prediction = transfer_model(img_tensor.to("cuda"))
    predicted_probabilities = torch.softmax(prediction, dim=1)
    predicted_class_idx = torch.argmax(prediction).item()
    predicted_class = orig_set.classes[predicted_class_idx]

    # Get the confidence score for the predicted class
    confidence = predicted_probabilities[0, predicted_class_idx].item() * 100  # Convert to percentage

    return predicted_class, confidence

# %%
transforms_wt = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

orig_set = datasets.ImageFolder(
    root='C:\\Users\\Pirmin.000\\PycharmProjects\\IGP\\data\\tool_finder\\10_11_2023_21_05_33',
    transform=transforms_wt
)
orig_set.classes
transfer_model = models.resnet152()
transfer_model.fc = nn.Sequential(
    nn.Linear(transfer_model.fc.in_features, 2048),
    nn.ReLU(),
    nn.Dropout(),
    nn.Linear(2048, 1024),
    nn.ReLU(),
    nn.Dropout(),
    nn.Linear(1024, 500),
    nn.ReLU(),
    nn.Dropout(),
    nn.Linear(500, 2)
)
transfer_model_state_dict = torch.load(
    "C:\\Users\\Pirmin.000\\PycharmProjects\\IGP\\models\\tool_finder\\10_11_2023_21_05_33\\model.pt")
transfer_model.load_state_dict(transfer_model_state_dict)
transfer_model.to("cuda")
transfer_model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=2048, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=2048, out_features=1024, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=1024, out_features=500, bias=True)
#     (7): ReLU()
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=500, out_features=2, bias=True)
#   )
# )

# %%
directory = "tmp_tools"
if not os.path.exists(directory):
    os.makedirs(directory)

for video_source_id in tqdm(unlabeled_loops):
    video_source = toolcheck.get_filepath_by_loop_id(video_source_id)
    video_to_image_converter(video_source, directory, True)
    dataset = []
    conf = []
    
    for filename in os.listdir(directory):
        f = os.path.join(directory, filename)
        predicted_class, confidence = checkImage(f, transfer_model, orig_set, transforms_wt)
        conf.append(confidence)
        dataset.append(predicted_class)
    
        os.remove(f)
    os.rmdir(directory)
    dataset_confidence = sum(conf) / len(conf)
    tool_timer = Counter(dataset)
    for classes in orig_set.classes:
        toolcheck.set_tool_timer(video_source_id, classes,time_formatter(tool_timer[classes]))

    print(f"Loop_id: {video_source_id}, Result{Counter(dataset)}")
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 2023-11-28 18:41:36,062 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:41:36,062 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {'loop_id': 129}
# 2023-11-28 18:41:50,791 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:41:50,793 INFO sqlalchemy.engine.Engine [generated in 0.00095s] {'id_1': 129, 'param_1': 1}
# 2023-11-28 18:41:50,797 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:41:50,798 INFO sqlalchemy.engine.Engine [generated in 0.00068s] {'param_1': 129}
# 2023-11-28 18:41:50,801 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:41:50,802 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:41:50,803 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:41:50,803 INFO sqlalchemy.engine.Engine [cached since 0.0111s ago] {'id_1': 129, 'param_1': 1}
# 2023-11-28 18:41:50,805 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:41:50,805 INFO sqlalchemy.engine.Engine [cached since 0.008147s ago] {'param_1': 129}
# 2023-11-28 18:41:50,808 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:41:50,809 INFO sqlalchemy.engine.Engine [generated in 0.00063s] {'tool': 'duoballs', 'time_in_use': '00:00:43'}
# 2023-11-28 18:41:50,810 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:41:50,811 INFO sqlalchemy.engine.Engine [generated in 0.00058s] {'tool_id': 5, 'loop_id': 129}
# 2023-11-28 18:41:50,812 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:41:50,815 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:41:50,815 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:41:50,816 INFO sqlalchemy.engine.Engine [cached since 0.02349s ago] {'id_1': 129, 'param_1': 1}
# 2023-11-28 18:41:50,817 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:41:50,818 INFO sqlalchemy.engine.Engine [cached since 0.0211s ago] {'param_1': 129}
# 2023-11-28 18:41:50,819 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:41:50,821 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:41:50,821 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:41:50,822 INFO sqlalchemy.engine.Engine [cached since 0.03002s ago] {'id_1': 129, 'param_1': 1}
# 2023-11-28 18:41:50,824 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:41:50,824 INFO sqlalchemy.engine.Engine [cached since 0.02741s ago] {'param_1': 129}
# 2023-11-28 18:41:50,826 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:41:50,827 INFO sqlalchemy.engine.Engine [cached since 0.01948s ago] {'tool': 'trigger', 'time_in_use': '00:00:35'}
# 2023-11-28 18:41:50,829 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:41:50,829 INFO sqlalchemy.engine.Engine [cached since 0.01896s ago] {'tool_id': 6, 'loop_id': 129}
# 2023-11-28 18:41:50,831 INFO sqlalchemy.engine.Engine COMMIT
#   5%|▍         | 1/22 [00:14<05:10, 14.77s/it]
# Loop_id: 129, ResultCounter({'duoballs': 43, 'trigger': 35})
# 2023-11-28 18:41:50,833 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:41:50,833 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:41:50,834 INFO sqlalchemy.engine.Engine [cached since 14.77s ago] {'loop_id': 130}
# 2023-11-28 18:42:12,839 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:12,840 INFO sqlalchemy.engine.Engine [cached since 22.05s ago] {'id_1': 130, 'param_1': 1}
# 2023-11-28 18:42:12,842 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:12,843 INFO sqlalchemy.engine.Engine [cached since 22.05s ago] {'param_1': 130}
# 2023-11-28 18:42:12,844 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:12,845 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:12,846 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:12,847 INFO sqlalchemy.engine.Engine [cached since 22.05s ago] {'id_1': 130, 'param_1': 1}
# 2023-11-28 18:42:12,848 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:12,848 INFO sqlalchemy.engine.Engine [cached since 22.05s ago] {'param_1': 130}
# 2023-11-28 18:42:12,850 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:42:12,851 INFO sqlalchemy.engine.Engine [cached since 22.04s ago] {'tool': 'duoballs', 'time_in_use': '00:01:11'}
# 2023-11-28 18:42:12,852 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:42:12,852 INFO sqlalchemy.engine.Engine [cached since 22.04s ago] {'tool_id': 7, 'loop_id': 130}
# 2023-11-28 18:42:12,853 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:12,854 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:12,855 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:12,856 INFO sqlalchemy.engine.Engine [cached since 22.06s ago] {'id_1': 130, 'param_1': 1}
# 2023-11-28 18:42:12,857 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:12,858 INFO sqlalchemy.engine.Engine [cached since 22.06s ago] {'param_1': 130}
# 2023-11-28 18:42:12,859 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:12,861 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:12,861 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:12,862 INFO sqlalchemy.engine.Engine [cached since 22.07s ago] {'id_1': 130, 'param_1': 1}
# 2023-11-28 18:42:12,863 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:12,864 INFO sqlalchemy.engine.Engine [cached since 22.07s ago] {'param_1': 130}
# 2023-11-28 18:42:12,865 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:42:12,865 INFO sqlalchemy.engine.Engine [cached since 22.06s ago] {'tool': 'trigger', 'time_in_use': '00:00:49'}
# 2023-11-28 18:42:12,867 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:42:12,867 INFO sqlalchemy.engine.Engine [cached since 22.06s ago] {'tool_id': 8, 'loop_id': 130}
# 2023-11-28 18:42:12,868 INFO sqlalchemy.engine.Engine COMMIT
#   9%|▉         | 2/22 [00:36<06:20, 19.05s/it]
# Loop_id: 130, ResultCounter({'duoballs': 71, 'trigger': 49})
# 2023-11-28 18:42:12,870 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:12,870 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:42:12,871 INFO sqlalchemy.engine.Engine [cached since 36.81s ago] {'loop_id': 131}
# 2023-11-28 18:42:31,031 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:31,033 INFO sqlalchemy.engine.Engine [cached since 40.24s ago] {'id_1': 131, 'param_1': 1}
# 2023-11-28 18:42:31,035 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:31,035 INFO sqlalchemy.engine.Engine [cached since 40.24s ago] {'param_1': 131}
# 2023-11-28 18:42:31,037 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:31,038 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:31,038 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:31,039 INFO sqlalchemy.engine.Engine [cached since 40.25s ago] {'id_1': 131, 'param_1': 1}
# 2023-11-28 18:42:31,040 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:31,041 INFO sqlalchemy.engine.Engine [cached since 40.24s ago] {'param_1': 131}
# 2023-11-28 18:42:31,042 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:42:31,043 INFO sqlalchemy.engine.Engine [cached since 40.23s ago] {'tool': 'duoballs', 'time_in_use': '00:00:00'}
# 2023-11-28 18:42:31,044 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:42:31,044 INFO sqlalchemy.engine.Engine [cached since 40.23s ago] {'tool_id': 9, 'loop_id': 131}
# 2023-11-28 18:42:31,045 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:31,047 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:31,047 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:31,048 INFO sqlalchemy.engine.Engine [cached since 40.26s ago] {'id_1': 131, 'param_1': 1}
# 2023-11-28 18:42:31,049 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:31,049 INFO sqlalchemy.engine.Engine [cached since 40.25s ago] {'param_1': 131}
# 2023-11-28 18:42:31,050 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:31,052 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:31,053 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:31,053 INFO sqlalchemy.engine.Engine [cached since 40.26s ago] {'id_1': 131, 'param_1': 1}
# 2023-11-28 18:42:31,054 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:31,055 INFO sqlalchemy.engine.Engine [cached since 40.26s ago] {'param_1': 131}
# 2023-11-28 18:42:31,056 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:42:31,057 INFO sqlalchemy.engine.Engine [cached since 40.25s ago] {'tool': 'trigger', 'time_in_use': '00:01:38'}
# 2023-11-28 18:42:31,058 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:42:31,058 INFO sqlalchemy.engine.Engine [cached since 40.25s ago] {'tool_id': 10, 'loop_id': 131}
# 2023-11-28 18:42:31,059 INFO sqlalchemy.engine.Engine COMMIT
#  14%|█▎        | 3/22 [00:54<05:54, 18.66s/it]
# Loop_id: 131, ResultCounter({'trigger': 98})
# 2023-11-28 18:42:31,062 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:31,062 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:42:31,063 INFO sqlalchemy.engine.Engine [cached since 55s ago] {'loop_id': 132}
# 2023-11-28 18:42:53,659 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:53,660 INFO sqlalchemy.engine.Engine [cached since 62.87s ago] {'id_1': 132, 'param_1': 1}
# 2023-11-28 18:42:53,661 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:53,662 INFO sqlalchemy.engine.Engine [cached since 62.86s ago] {'param_1': 132}
# 2023-11-28 18:42:53,663 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:53,664 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:53,664 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:53,665 INFO sqlalchemy.engine.Engine [cached since 62.87s ago] {'id_1': 132, 'param_1': 1}
# 2023-11-28 18:42:53,666 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:53,667 INFO sqlalchemy.engine.Engine [cached since 62.87s ago] {'param_1': 132}
# 2023-11-28 18:42:53,668 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:42:53,669 INFO sqlalchemy.engine.Engine [cached since 62.86s ago] {'tool': 'duoballs', 'time_in_use': '00:01:20'}
# 2023-11-28 18:42:53,670 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:42:53,670 INFO sqlalchemy.engine.Engine [cached since 62.86s ago] {'tool_id': 11, 'loop_id': 132}
# 2023-11-28 18:42:53,671 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:53,673 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:53,673 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:53,674 INFO sqlalchemy.engine.Engine [cached since 62.88s ago] {'id_1': 132, 'param_1': 1}
# 2023-11-28 18:42:53,675 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:53,676 INFO sqlalchemy.engine.Engine [cached since 62.88s ago] {'param_1': 132}
# 2023-11-28 18:42:53,676 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:42:53,678 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:53,679 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:42:53,680 INFO sqlalchemy.engine.Engine [cached since 62.89s ago] {'id_1': 132, 'param_1': 1}
# 2023-11-28 18:42:53,681 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:42:53,682 INFO sqlalchemy.engine.Engine [cached since 62.88s ago] {'param_1': 132}
# 2023-11-28 18:42:53,684 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:42:53,685 INFO sqlalchemy.engine.Engine [cached since 62.88s ago] {'tool': 'trigger', 'time_in_use': '00:00:43'}
# 2023-11-28 18:42:53,686 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:42:53,687 INFO sqlalchemy.engine.Engine [cached since 62.88s ago] {'tool_id': 12, 'loop_id': 132}
# 2023-11-28 18:42:53,688 INFO sqlalchemy.engine.Engine COMMIT
#  18%|█▊        | 4/22 [01:17<06:04, 20.22s/it]
# Loop_id: 132, ResultCounter({'duoballs': 80, 'trigger': 43})
# 2023-11-28 18:42:53,691 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:42:53,691 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:42:53,692 INFO sqlalchemy.engine.Engine [cached since 77.63s ago] {'loop_id': 133}
# 2023-11-28 18:43:12,658 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:12,659 INFO sqlalchemy.engine.Engine [cached since 81.87s ago] {'id_1': 133, 'param_1': 1}
# 2023-11-28 18:43:12,661 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:12,661 INFO sqlalchemy.engine.Engine [cached since 81.87s ago] {'param_1': 133}
# 2023-11-28 18:43:12,663 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:12,664 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:12,665 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:12,665 INFO sqlalchemy.engine.Engine [cached since 81.87s ago] {'id_1': 133, 'param_1': 1}
# 2023-11-28 18:43:12,667 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:12,667 INFO sqlalchemy.engine.Engine [cached since 81.87s ago] {'param_1': 133}
# 2023-11-28 18:43:12,669 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:43:12,670 INFO sqlalchemy.engine.Engine [cached since 81.86s ago] {'tool': 'duoballs', 'time_in_use': '00:01:43'}
# 2023-11-28 18:43:12,671 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:43:12,671 INFO sqlalchemy.engine.Engine [cached since 81.86s ago] {'tool_id': 13, 'loop_id': 133}
# 2023-11-28 18:43:12,672 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:12,674 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:12,674 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:12,675 INFO sqlalchemy.engine.Engine [cached since 81.88s ago] {'id_1': 133, 'param_1': 1}
# 2023-11-28 18:43:12,676 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:12,677 INFO sqlalchemy.engine.Engine [cached since 81.88s ago] {'param_1': 133}
# 2023-11-28 18:43:12,678 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:12,679 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:12,679 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:12,680 INFO sqlalchemy.engine.Engine [cached since 81.89s ago] {'id_1': 133, 'param_1': 1}
# 2023-11-28 18:43:12,681 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:12,682 INFO sqlalchemy.engine.Engine [cached since 81.89s ago] {'param_1': 133}
# 2023-11-28 18:43:12,684 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:43:12,685 INFO sqlalchemy.engine.Engine [cached since 81.88s ago] {'tool': 'trigger', 'time_in_use': '00:00:00'}
# 2023-11-28 18:43:12,686 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:43:12,687 INFO sqlalchemy.engine.Engine [cached since 81.88s ago] {'tool_id': 14, 'loop_id': 133}
# 2023-11-28 18:43:12,688 INFO sqlalchemy.engine.Engine COMMIT
#  23%|██▎       | 5/22 [01:36<05:36, 19.78s/it]
# Loop_id: 133, ResultCounter({'duoballs': 103})
# 2023-11-28 18:43:12,690 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:12,690 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:43:12,691 INFO sqlalchemy.engine.Engine [cached since 96.63s ago] {'loop_id': 134}
# 2023-11-28 18:43:21,768 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:21,769 INFO sqlalchemy.engine.Engine [cached since 90.98s ago] {'id_1': 134, 'param_1': 1}
# 2023-11-28 18:43:21,770 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:21,771 INFO sqlalchemy.engine.Engine [cached since 90.97s ago] {'param_1': 134}
# 2023-11-28 18:43:21,772 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:21,773 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:21,774 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:21,775 INFO sqlalchemy.engine.Engine [cached since 90.98s ago] {'id_1': 134, 'param_1': 1}
# 2023-11-28 18:43:21,777 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:21,778 INFO sqlalchemy.engine.Engine [cached since 90.98s ago] {'param_1': 134}
# 2023-11-28 18:43:21,779 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:43:21,780 INFO sqlalchemy.engine.Engine [cached since 90.97s ago] {'tool': 'duoballs', 'time_in_use': '00:00:51'}
# 2023-11-28 18:43:21,781 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:43:21,782 INFO sqlalchemy.engine.Engine [cached since 90.97s ago] {'tool_id': 15, 'loop_id': 134}
# 2023-11-28 18:43:21,783 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:21,785 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:21,786 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:21,787 INFO sqlalchemy.engine.Engine [cached since 91s ago] {'id_1': 134, 'param_1': 1}
# 2023-11-28 18:43:21,789 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:21,789 INFO sqlalchemy.engine.Engine [cached since 90.99s ago] {'param_1': 134}
# 2023-11-28 18:43:21,790 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:21,791 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:21,792 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:21,792 INFO sqlalchemy.engine.Engine [cached since 91s ago] {'id_1': 134, 'param_1': 1}
# 2023-11-28 18:43:21,794 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:21,794 INFO sqlalchemy.engine.Engine [cached since 91s ago] {'param_1': 134}
# 2023-11-28 18:43:21,796 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:43:21,797 INFO sqlalchemy.engine.Engine [cached since 90.99s ago] {'tool': 'trigger', 'time_in_use': '00:00:00'}
# 2023-11-28 18:43:21,798 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:43:21,798 INFO sqlalchemy.engine.Engine [cached since 90.99s ago] {'tool_id': 16, 'loop_id': 134}
# 2023-11-28 18:43:21,800 INFO sqlalchemy.engine.Engine COMMIT
#  27%|██▋       | 6/22 [01:45<04:18, 16.15s/it]
# Loop_id: 134, ResultCounter({'duoballs': 51})
# 2023-11-28 18:43:21,801 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:21,802 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:43:21,803 INFO sqlalchemy.engine.Engine [cached since 105.7s ago] {'loop_id': 135}
# 2023-11-28 18:43:54,278 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:54,280 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'id_1': 135, 'param_1': 1}
# 2023-11-28 18:43:54,282 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:54,282 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'param_1': 135}
# 2023-11-28 18:43:54,284 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:54,285 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:54,286 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:54,287 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'id_1': 135, 'param_1': 1}
# 2023-11-28 18:43:54,288 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:54,289 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'param_1': 135}
# 2023-11-28 18:43:54,291 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:43:54,291 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'tool': 'duoballs', 'time_in_use': '00:01:10'}
# 2023-11-28 18:43:54,292 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:43:54,293 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'tool_id': 17, 'loop_id': 135}
# 2023-11-28 18:43:54,294 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:54,295 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:54,296 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:54,297 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'id_1': 135, 'param_1': 1}
# 2023-11-28 18:43:54,298 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:54,299 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'param_1': 135}
# 2023-11-28 18:43:54,300 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:43:54,301 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:54,302 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:43:54,302 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'id_1': 135, 'param_1': 1}
# 2023-11-28 18:43:54,304 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:43:54,305 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'param_1': 135}
# 2023-11-28 18:43:54,307 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:43:54,307 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'tool': 'trigger', 'time_in_use': '00:01:40'}
# 2023-11-28 18:43:54,317 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:43:54,318 INFO sqlalchemy.engine.Engine [cached since 123.5s ago] {'tool_id': 18, 'loop_id': 135}
# 2023-11-28 18:43:54,320 INFO sqlalchemy.engine.Engine COMMIT
#  32%|███▏      | 7/22 [02:18<05:22, 21.50s/it]
# Loop_id: 135, ResultCounter({'trigger': 100, 'duoballs': 70})
# 2023-11-28 18:43:54,322 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:43:54,322 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:43:54,323 INFO sqlalchemy.engine.Engine [cached since 138.3s ago] {'loop_id': 136}
# 2023-11-28 18:44:17,812 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:17,813 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'id_1': 136, 'param_1': 1}
# 2023-11-28 18:44:17,814 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:17,815 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'param_1': 136}
# 2023-11-28 18:44:17,816 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:44:17,817 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:17,818 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:17,818 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'id_1': 136, 'param_1': 1}
# 2023-11-28 18:44:17,819 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:17,820 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'param_1': 136}
# 2023-11-28 18:44:17,821 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:44:17,821 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'tool': 'duoballs', 'time_in_use': '00:01:00'}
# 2023-11-28 18:44:17,822 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:44:17,823 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'tool_id': 19, 'loop_id': 136}
# 2023-11-28 18:44:17,823 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:44:17,824 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:17,825 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:17,825 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'id_1': 136, 'param_1': 1}
# 2023-11-28 18:44:17,826 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:17,827 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'param_1': 136}
# 2023-11-28 18:44:17,828 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:44:17,829 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:17,830 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:17,831 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'id_1': 136, 'param_1': 1}
# 2023-11-28 18:44:17,832 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:17,832 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'param_1': 136}
# 2023-11-28 18:44:17,834 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:44:17,835 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'tool': 'trigger', 'time_in_use': '00:01:08'}
# 2023-11-28 18:44:17,836 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:44:17,837 INFO sqlalchemy.engine.Engine [cached since 147s ago] {'tool_id': 20, 'loop_id': 136}
# 2023-11-28 18:44:17,839 INFO sqlalchemy.engine.Engine COMMIT
#  36%|███▋      | 8/22 [02:41<05:10, 22.15s/it]
# Loop_id: 136, ResultCounter({'trigger': 68, 'duoballs': 60})
# 2023-11-28 18:44:17,841 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:17,841 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:44:17,842 INFO sqlalchemy.engine.Engine [cached since 161.8s ago] {'loop_id': 137}
# 2023-11-28 18:44:48,947 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:48,948 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'id_1': 137, 'param_1': 1}
# 2023-11-28 18:44:48,950 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:48,950 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'param_1': 137}
# 2023-11-28 18:44:48,951 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:44:48,952 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:48,953 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:48,953 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'id_1': 137, 'param_1': 1}
# 2023-11-28 18:44:48,955 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:48,955 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'param_1': 137}
# 2023-11-28 18:44:48,956 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:44:48,957 INFO sqlalchemy.engine.Engine [cached since 178.1s ago] {'tool': 'duoballs', 'time_in_use': '00:01:42'}
# 2023-11-28 18:44:48,957 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:44:48,958 INFO sqlalchemy.engine.Engine [cached since 178.1s ago] {'tool_id': 21, 'loop_id': 137}
# 2023-11-28 18:44:48,959 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:44:48,960 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:48,960 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:48,961 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'id_1': 137, 'param_1': 1}
# 2023-11-28 18:44:48,963 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:48,963 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'param_1': 137}
# 2023-11-28 18:44:48,964 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:44:48,965 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:48,965 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:44:48,966 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'id_1': 137, 'param_1': 1}
# 2023-11-28 18:44:48,968 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:44:48,968 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'param_1': 137}
# 2023-11-28 18:44:48,970 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:44:48,970 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'tool': 'trigger', 'time_in_use': '00:00:58'}
# 2023-11-28 18:44:48,971 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:44:48,971 INFO sqlalchemy.engine.Engine [cached since 178.2s ago] {'tool_id': 22, 'loop_id': 137}
# 2023-11-28 18:44:48,972 INFO sqlalchemy.engine.Engine COMMIT
#  41%|████      | 9/22 [03:12<05:24, 24.96s/it]
# Loop_id: 137, ResultCounter({'duoballs': 102, 'trigger': 58})
# 2023-11-28 18:44:48,974 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:44:48,975 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:44:48,975 INFO sqlalchemy.engine.Engine [cached since 192.9s ago] {'loop_id': 138}
# 2023-11-28 18:45:11,779 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:45:11,781 INFO sqlalchemy.engine.Engine [cached since 201s ago] {'id_1': 138, 'param_1': 1}
# 2023-11-28 18:45:11,783 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:45:11,784 INFO sqlalchemy.engine.Engine [cached since 201s ago] {'param_1': 138}
# 2023-11-28 18:45:11,785 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:45:11,786 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:45:11,787 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:45:11,788 INFO sqlalchemy.engine.Engine [cached since 201s ago] {'id_1': 138, 'param_1': 1}
# 2023-11-28 18:45:11,789 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# ...
# 2023-11-28 18:45:11,812 INFO sqlalchemy.engine.Engine [cached since 201s ago] {'tool_id': 24, 'loop_id': 138}
# 2023-11-28 18:45:11,812 INFO sqlalchemy.engine.Engine COMMIT
#  45%|████▌     | 10/22 [03:35<04:51, 24.30s/it]
# Loop_id: 138, ResultCounter({'trigger': 118})
# 2023-11-28 18:45:11,814 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:45:11,815 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:45:11,815 INFO sqlalchemy.engine.Engine [cached since 215.8s ago] {'loop_id': 139}
# 2023-11-28 18:45:37,720 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:45:37,722 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'id_1': 139, 'param_1': 1}
# 2023-11-28 18:45:37,724 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:45:37,724 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'param_1': 139}
# 2023-11-28 18:45:37,725 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:45:37,726 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:45:37,728 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:45:37,728 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'id_1': 139, 'param_1': 1}
# 2023-11-28 18:45:37,730 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:45:37,730 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'param_1': 139}
# 2023-11-28 18:45:37,732 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:45:37,733 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'tool': 'duoballs', 'time_in_use': '00:01:08'}
# 2023-11-28 18:45:37,734 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:45:37,734 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'tool_id': 25, 'loop_id': 139}
# 2023-11-28 18:45:37,735 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:45:37,736 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:45:37,737 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:45:37,737 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'id_1': 139, 'param_1': 1}
# 2023-11-28 18:45:37,739 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:45:37,739 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'param_1': 139}
# 2023-11-28 18:45:37,740 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:45:37,741 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:45:37,742 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:45:37,743 INFO sqlalchemy.engine.Engine [cached since 227s ago] {'id_1': 139, 'param_1': 1}
# 2023-11-28 18:45:37,744 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:45:37,744 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'param_1': 139}
# 2023-11-28 18:45:37,746 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:45:37,747 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'tool': 'trigger', 'time_in_use': '00:01:04'}
# 2023-11-28 18:45:37,748 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:45:37,749 INFO sqlalchemy.engine.Engine [cached since 226.9s ago] {'tool_id': 26, 'loop_id': 139}
# 2023-11-28 18:45:37,749 INFO sqlalchemy.engine.Engine COMMIT
#  50%|█████     | 11/22 [04:01<04:32, 24.80s/it]
# Loop_id: 139, ResultCounter({'duoballs': 68, 'trigger': 64})
# 2023-11-28 18:45:37,751 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:45:37,752 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:45:37,752 INFO sqlalchemy.engine.Engine [cached since 241.7s ago] {'loop_id': 140}
# 2023-11-28 18:46:09,157 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:09,158 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'id_1': 140, 'param_1': 1}
# 2023-11-28 18:46:09,160 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:09,160 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'param_1': 140}
# 2023-11-28 18:46:09,161 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:46:09,163 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:09,163 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:09,164 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'id_1': 140, 'param_1': 1}
# 2023-11-28 18:46:09,166 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:09,166 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'param_1': 140}
# 2023-11-28 18:46:09,168 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:46:09,169 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'tool': 'duoballs', 'time_in_use': '00:01:34'}
# 2023-11-28 18:46:09,170 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:46:09,171 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'tool_id': 27, 'loop_id': 140}
# 2023-11-28 18:46:09,172 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:46:09,173 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:09,174 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:09,174 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'id_1': 140, 'param_1': 1}
# 2023-11-28 18:46:09,176 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:09,176 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'param_1': 140}
# 2023-11-28 18:46:09,177 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:46:09,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:09,179 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:09,179 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'id_1': 140, 'param_1': 1}
# 2023-11-28 18:46:09,180 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:09,181 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'param_1': 140}
# 2023-11-28 18:46:09,182 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:46:09,182 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'tool': 'trigger', 'time_in_use': '00:01:04'}
# 2023-11-28 18:46:09,183 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:46:09,184 INFO sqlalchemy.engine.Engine [cached since 258.4s ago] {'tool_id': 28, 'loop_id': 140}
# 2023-11-28 18:46:09,184 INFO sqlalchemy.engine.Engine COMMIT
#  55%|█████▍    | 12/22 [04:33<04:28, 26.82s/it]
# Loop_id: 140, ResultCounter({'duoballs': 94, 'trigger': 64})
# 2023-11-28 18:46:09,186 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:09,186 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:46:09,187 INFO sqlalchemy.engine.Engine [cached since 273.1s ago] {'loop_id': 141}
# 2023-11-28 18:46:40,034 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:40,035 INFO sqlalchemy.engine.Engine [cached since 289.2s ago] {'id_1': 141, 'param_1': 1}
# 2023-11-28 18:46:40,037 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:40,037 INFO sqlalchemy.engine.Engine [cached since 289.2s ago] {'param_1': 141}
# 2023-11-28 18:46:40,039 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:46:40,040 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:40,041 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:40,041 INFO sqlalchemy.engine.Engine [cached since 289.2s ago] {'id_1': 141, 'param_1': 1}
# 2023-11-28 18:46:40,042 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:40,043 INFO sqlalchemy.engine.Engine [cached since 289.2s ago] {'param_1': 141}
# 2023-11-28 18:46:40,044 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:46:40,045 INFO sqlalchemy.engine.Engine [cached since 289.2s ago] {'tool': 'duoballs', 'time_in_use': '00:02:37'}
# 2023-11-28 18:46:40,046 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:46:40,046 INFO sqlalchemy.engine.Engine [cached since 289.2s ago] {'tool_id': 29, 'loop_id': 141}
# 2023-11-28 18:46:40,047 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:46:40,049 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:40,050 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:40,050 INFO sqlalchemy.engine.Engine [cached since 289.3s ago] {'id_1': 141, 'param_1': 1}
# 2023-11-28 18:46:40,051 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:40,052 INFO sqlalchemy.engine.Engine [cached since 289.3s ago] {'param_1': 141}
# 2023-11-28 18:46:40,053 INFO sqlalchemy.engine.Engine COMMIT
# 2023-11-28 18:46:40,054 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:40,054 INFO sqlalchemy.engine.Engine SELECT loop.id AS loop_id, loop.timestamp AS loop_timestamp, loop.session_length AS loop_session_length, loop.location AS loop_location, loop.human_labeled AS loop_human_labeled, loop.user_id AS loop_user_id
# FROM loop
# WHERE loop.id = %(id_1)s
#  LIMIT %(param_1)s
# 2023-11-28 18:46:40,055 INFO sqlalchemy.engine.Engine [cached since 289.3s ago] {'id_1': 141, 'param_1': 1}
# 2023-11-28 18:46:40,056 INFO sqlalchemy.engine.Engine SELECT tools.id AS tools_id, tools.tool AS tools_tool, tools.time_in_use AS tools_time_in_use
# FROM tools, tools_loop_association
# WHERE %(param_1)s = tools_loop_association.loop_id AND tools.id = tools_loop_association.tool_id
# 2023-11-28 18:46:40,057 INFO sqlalchemy.engine.Engine [cached since 289.3s ago] {'param_1': 141}
# 2023-11-28 18:46:40,058 INFO sqlalchemy.engine.Engine INSERT INTO tools (tool, time_in_use) VALUES (%(tool)s, %(time_in_use)s) RETURNING tools.id
# 2023-11-28 18:46:40,058 INFO sqlalchemy.engine.Engine [cached since 289.3s ago] {'tool': 'trigger', 'time_in_use': '00:00:05'}
# 2023-11-28 18:46:40,060 INFO sqlalchemy.engine.Engine INSERT INTO tools_loop_association (tool_id, loop_id) VALUES (%(tool_id)s, %(loop_id)s)
# 2023-11-28 18:46:40,060 INFO sqlalchemy.engine.Engine [cached since 289.3s ago] {'tool_id': 30, 'loop_id': 141}
# 2023-11-28 18:46:40,061 INFO sqlalchemy.engine.Engine COMMIT
#  59%|█████▉    | 13/22 [05:04<04:12, 28.05s/it]
# Loop_id: 141, ResultCounter({'duoballs': 157, 'trigger': 5})
# 2023-11-28 18:46:40,063 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2023-11-28 18:46:40,064 INFO sqlalchemy.engine.Engine SELECT file_path FROM video WHERE loop_id = %(loop_id)s AND device = 'rgbCam'
# 2023-11-28 18:46:40,064 INFO sqlalchemy.engine.Engine [cached since 304s ago] {'loop_id': 142}
